# %%
import matplotlib.pyplot as plt

x=[0,5000,10000,15000,20000]

SVM= [0,72.54,76.24,79.33,82.91]

KNN= [0,69.22,50.57,55.30,57.74]

Naive_Bayes = [0,70.55,75.24,76.02,80.36]

Maximum_Entropy = [0,57.79,58.79,49.79,32.63]

Lexicon =  [0,40.28,48.93,50.98,53.23]

plt.plot(x,SVM,color='navy',label='SVM',linestyle="--")
plt.plot(x,KNN,color='maroon',label='KNN',linestyle="--")
plt.plot(x,Naive_Bayes,color='gold',label='Naive Bayes',linestyle="--")
plt.plot(x,Maximum_Entropy,color='darkgreen',label='Maximum Entropy',linestyle="--")
plt.plot(x,Lexicon,color='black',label='Lexicon',linestyle="--")

#plt.plot(x,SVM,KNN,Naive_Bayes,Maximum_Entropy,Lexicon,colors=['navy','royalblue','cyan','steelblue','darkslategrey'])

plt.xlabel('Weight of the Dataset')
plt.ylabel('Accuracy Rate')
plt.title('Accuracy of various classifiers vs Weight')
plt.legend()
plt.show()
